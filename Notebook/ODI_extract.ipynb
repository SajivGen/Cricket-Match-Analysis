# %%
import json
import pandas as pd 
import os

# %%
class ODIdata:
    def __init__(self, season, city, venue, date, match_type, match_type_number,teams, toss_winner, toss_decision, outcome_by_runs, outcome_by_wickets, winner, player_of_match, target, innings):
        self.season = season
        self.city = city
        self.venue = venue
        self.date = date
        self.match_type = match_type
        self.match_type_number = match_type_number
        self.teams = teams
        self.toss_winner = toss_winner
        self.toss_decision = toss_decision
        self.outcome_by_runs = outcome_by_runs
        self.outcome_by_wickets = outcome_by_wickets
        self.winner = winner
        self.player_of_match = player_of_match
        self.target = target
        self.innings = innings

    def to_dict(self):
        return{
            'season': self.season,
            'city': self.city,
            'venue': self.venue,
            'date': self.date,
            'match_type': self.match_type,
            'match_type_number': self.match_type_number,
            'teams': self.teams,
            'toss_winner': self.toss_winner,
            'toss_decision': self.toss_decision,
            'outcome_by_runs': self.outcome_by_runs,
            'outcome_by_wickets': self.outcome_by_wickets,
            'winner': self.winner,
            'player_of_match': ', '.join(self.player_of_match),
            'target': self.target
        }    

    def innings_dict(self):
        innings_data = []
        for inning in self.innings:
            team = inning['team']
            for over in inning['overs']:
                for delivery in over['deliveries']:
                    innings_data.append({
                        'season': self.season,
                        'match_type_number': self.match_type_number,
                        'team': team,
                        'over': over['over'],
                        'batter': delivery['batter'],
                        'bowler': delivery['bowler'],
                        'runs_batter': delivery['runs'].get('batter', 0),
                        'runs_extras': delivery['runs'].get('extras', 0),
                        'runs_total': delivery['runs'].get('total', 0),
                        'non_striker': delivery['non_striker'],

                    })
        return innings_data

# %%
class ODIdataloader:
    def __init__(self,folder_path):
        self.folder_path = folder_path
        self.matches = []

    def load_data(self):
        if not os.path.exists(self.folder_path):
            print(f"Error: The folder {self.folder_path} does not exist.")
            return
        
        json_files = [f for f in os.listdir(self.folder_path) if f.endswith('.json')]

        if not json_files:
            print(f"Error: No JSON files found in the folder {self.folder_path}.")
            return
        
        for json_file in json_files:
            try:
                file_path = os.path.join(self.folder_path, json_file)
                with open(file_path, 'r') as file:
                    data = json.load(file)

                    season = data['info'].get('season', 'N/A')  
                    city = data['info'].get('city', 'N/A')
                    venue = data['info'].get('venue', 'N/A')
                    date = data['info']['dates'][0] if 'dates' in data['info'] else 'N/A'
                    match_type = data['info'].get('match_type', 'N/A')
                    match_type_number = data['info'].get('match_type_number','N/A')
                    teams = data['info'].get('teams', [])
                    toss_winner = data['info']['toss'].get('winner', 'N/A') if 'toss' in data['info'] else 'N/A'
                    toss_decision = data['info']['toss'].get('decision', 'N/A') if 'toss' in data['info'] else 'N/A'
                    #outcome = f"Winner: {data['info'].get('outcome', {}).get('winner', 'N/A')}, By {data['info'].get('outcome', {}).get('by', {}).get('runs', 0)} runs"
                    outcome_by_runs = data['info']['outcome']['by'].get('runs', 'N/A') if 'by' in data['info']['outcome'] else 'N/A'
                    outcome_by_wickets = data['info']['outcome']['by'].get('wickets', 'N/A') if 'by' in data['info']['outcome'] else 'N/A'
                    winner = data['info']['outcome'].get('winner','N/A')
                    player_of_match = data['info'].get('player_of_match', [])
                    target= data['innings'][1].get('target', {}).get('runs', 'N/A')    
                    innings = data.get('innings', [])
                    
                    # Create an instance of CricketMatch
                    match = ODIdata(season, city, venue, date, match_type, match_type_number, teams, toss_winner, toss_decision, outcome_by_runs, outcome_by_wickets, winner, player_of_match, target, innings)
                    self.matches.append(match)

            except PermissionError:
                print(f"Error: Permission denied while trying to open the file {json_file}. Please check your file permissions.")
            except Exception as e:
                print(f"An unexpected error occurred with file {json_file}: {e}")

    def to_dataframe(self):
        # Convert list of CricketMatch objects to a pandas DataFrame for match data
        match_data = [match.to_dict() for match in self.matches]
        match_df = pd.DataFrame(match_data)

        # Convert innings data to a DataFrame
        innings_data = []
        for match in self.matches:
            innings_data.extend(match.innings_dict())
        innings_df = pd.DataFrame(innings_data)

        return match_df, innings_df

# %%
folder_path = 'C:/Users/Sajiv/Documents/Cricket/one_day'  

print(f"Current working directory: {os.getcwd()}")

loader = ODIdataloader(folder_path)
loader.load_data()

if loader.matches:
    match_df, innings_df = loader.to_dataframe()

    # Displaying the DataFrames
    print("\nMatch DataFrame:")
    print(match_df)

    print("\nInnings DataFrame:")
    print(innings_df)
else:
    print("No data loaded. Please check the error messages above.")
# Out:
# Current working directory: c:\Users\Sajiv\Documents\Cricket\Notebook
# An unexpected error occurred with file 1031669.json: list index out of range
# An unexpected error occurred with file 1033361.json: list index out of range
# An unexpected error occurred with file 1059713.json: list index out of range
# An unexpected error occurred with file 1083447.json: list index out of range
# An unexpected error occurred with file 1098206.json: list index out of range
# An unexpected error occurred with file 1140379.json: list index out of range
# An unexpected error occurred with file 1144497.json: list index out of range
# An unexpected error occurred with file 1152841.json: list index out of range
# An unexpected error occurred with file 1185311.json: list index out of range
# An unexpected error occurred with file 1188624.json: list index out of range
# An unexpected error occurred with file 1208346.json: list index out of range
# An unexpected error occurred with file 1239536.json: list index out of range
# An unexpected error occurred with file 1243930.json: list index out of range
# An unexpected error occurred with file 1251950.json: list index out of range
# An unexpected error occurred with file 1272380.json: list index out of range
# An unexpected error occurred with file 1275260.json: list index out of range
# An unexpected error occurred with file 1276912.json: list index out of range
# An unexpected error occurred with file 1322279.json: list index out of range
# An unexpected error occurred with file 1322343.json: list index out of range
# An unexpected error occurred with file 1336084.json: list index out of range
# An unexpected error occurred with file 1336130.json: list index out of range
# An unexpected error occurred with file 1348328.json: list index out of range
# An unexpected error occurred with file 1355718.json: list index out of range
# An unexpected error occurred with file 1368849.json: list index out of range
# An unexpected error occurred with file 1375867.json: list index out of range
# An unexpected error occurred with file 1378192.json: list index out of range
# An unexpected error occurred with file 1388394.json: list index out of range
# An unexpected error occurred with file 1395700.json: list index out of range
# An unexpected error occurred with file 1398272.json: list index out of range
# An unexpected error occurred with file 1408106.json: list index out of range
# An unexpected error occurred with file 1450707.json: list index out of range
# An unexpected error occurred with file 1456445.json: list index out of range
# An unexpected error occurred with file 224044.json: list index out of range
# An unexpected error occurred with file 238213.json: list index out of range
# An unexpected error occurred with file 250670.json: list index out of range
# An unexpected error occurred with file 256665.json: list index out of range
# An unexpected error occurred with file 267710.json: list index out of range
# An unexpected error occurred with file 291346.json: list index out of range
# An unexpected error occurred with file 291360.json: list index out of range
# An unexpected error occurred with file 295785.json: list index out of range
# An unexpected error occurred with file 295788.json: list index out of range
# An unexpected error occurred with file 296918.json: list index out of range
# An unexpected error occurred with file 325576.json: list index out of range
# An unexpected error occurred with file 366626.json: list index out of range
# An unexpected error occurred with file 366709.json: list index out of range
# An unexpected error occurred with file 377316.json: list index out of range
# An unexpected error occurred with file 415281.json: list index out of range
# An unexpected error occurred with file 430890.json: list index out of range
# An unexpected error occurred with file 433577.json: list index out of range
# An unexpected error occurred with file 464990.json: list index out of range
# An unexpected error occurred with file 473315.json: list index out of range
# An unexpected error occurred with file 473924.json: list index out of range
# An unexpected error occurred with file 534214.json: list index out of range
# An unexpected error occurred with file 534228.json: list index out of range
# An unexpected error occurred with file 562441.json: list index out of range
# An unexpected error occurred with file 566943.json: list index out of range
# An unexpected error occurred with file 582191.json: list index out of range
# An unexpected error occurred with file 602475.json: list index out of range
# An unexpected error occurred with file 648655.json: list index out of range
# An unexpected error occurred with file 64889.json: list index out of range
# An unexpected error occurred with file 65273.json: list index out of range
# An unexpected error occurred with file 65652.json: list index out of range
# An unexpected error occurred with file 66296.json: list index out of range
# An unexpected error occurred with file 66356.json: list index out of range
# An unexpected error occurred with file 66364.json: list index out of range
# An unexpected error occurred with file 66375.json: list index out of range
# An unexpected error occurred with file 744683.json: list index out of range
# An unexpected error occurred with file 749775.json: list index out of range
# An unexpected error occurred with file 749785.json: list index out of range
# An unexpected error occurred with file 754757.json: list index out of range
# An unexpected error occurred with file 757505.json: list index out of range
# An unexpected error occurred with file 760889.json: list index out of range
# An unexpected error occurred with file 914213.json: list index out of range
# An unexpected error occurred with file 932861.json: list index out of range
#
# Match DataFrame:
#        season       city                                         venue  \
# 0     2016/17   Brisbane        Brisbane Cricket Ground, Woolloongabba
# 1     2016/17        N/A                      Melbourne Cricket Ground
# 2     2016/17      Perth  Western Australia Cricket Association Ground
# 3     2016/17        N/A                         Sydney Cricket Ground
# 4     2016/17        N/A                                 Adelaide Oval
# ...       ...        ...                                           ...
# 2814     2016        N/A        Rangiri Dambulla International Stadium
# 2815     2016        N/A        Rangiri Dambulla International Stadium
# 2816     2016        N/A       Pallekele International Cricket Stadium
# 2817     2016  Edinburgh     Grange Cricket Club Ground, Raeburn Place
# 2818     2016  Edinburgh     Grange Cricket Club Ground, Raeburn Place
#
#             date match_type  match_type_number  \
# 0     2017-01-13        ODI               3817
# 1     2017-01-15        ODI               3818
# 2     2017-01-19        ODI               3820
# 3     2017-01-22        ODI               3822
# 4     2017-01-26        ODI               3826
# ...          ...        ...                ...
# 2814  2016-08-28        ODI               3772
# 2815  2016-08-31        ODI               3774
# 2816  2016-09-04        ODI               3776
# 2817  2016-08-14        ODI               3765
# 2818  2016-08-16        ODI               3766
#
#                                  teams           toss_winner toss_decision  \
# 0                [Australia, Pakistan]             Australia           bat
# 1                [Australia, Pakistan]             Australia           bat
# 2                [Australia, Pakistan]             Australia         field
# 3                [Australia, Pakistan]             Australia           bat
# 4                [Australia, Pakistan]             Australia           bat
# ...                                ...                   ...           ...
# 2814            [Sri Lanka, Australia]             Sri Lanka           bat
# 2815            [Sri Lanka, Australia]             Sri Lanka           bat
# 2816            [Sri Lanka, Australia]             Sri Lanka           bat
# 2817  [Scotland, United Arab Emirates]  United Arab Emirates         field
# 2818  [Scotland, United Arab Emirates]  United Arab Emirates           bat
#
#      outcome_by_runs outcome_by_wickets     winner  player_of_match target
# 0                 92                N/A  Australia          MS Wade    269
# 1                N/A                  6   Pakistan  Mohammad Hafeez    221
# 2                N/A                  7  Australia        SPD Smith    264
# 3                 86                N/A  Australia        DA Warner    354
# 4                 57                N/A  Australia        DA Warner    370
# ...              ...                ...        ...              ...    ...
# 2814             N/A                  2  Australia        GJ Bailey    227
# 2815             N/A                  6  Australia      JW Hastings    213
# 2816             N/A                  5  Australia        DA Warner    196
# 2817              98                N/A   Scotland                     328
# 2818             N/A                  7   Scotland                     229
#
# [2819 rows x 14 columns]
#
# Innings DataFrame:
#           season  match_type_number       team  over         batter  \
# 0        2016/17               3817  Australia     0      DA Warner
# 1        2016/17               3817  Australia     0      DA Warner
# 2        2016/17               3817  Australia     0      DA Warner
# 3        2016/17               3817  Australia     0      DA Warner
# 4        2016/17               3817  Australia     0      DA Warner
# ...          ...                ...        ...   ...            ...
# 1520075     2016               3766   Scotland    46     PL Mommsen
# 1520076     2016               3766   Scotland    47  RD Berrington
# 1520077     2016               3766   Scotland    47  RD Berrington
# 1520078     2016               3766   Scotland    47  RD Berrington
# 1520079     2016               3766   Scotland    47  RD Berrington
#
#                    bowler  runs_batter  runs_extras  runs_total    non_striker
# 0           Mohammad Amir            0            0           0        TM Head
# 1           Mohammad Amir            0            0           0        TM Head
# 2           Mohammad Amir            0            0           0        TM Head
# 3           Mohammad Amir            0            0           0        TM Head
# 4           Mohammad Amir            0            1           1        TM Head
# ...                   ...          ...          ...         ...            ...
# 1520075  Mohammad Shahzad            0            0           0  RD Berrington
# 1520076     Rohan Mustafa            0            0           0     PL Mommsen
# 1520077     Rohan Mustafa            0            0           0     PL Mommsen
# 1520078     Rohan Mustafa            0            0           0     PL Mommsen
# 1520079     Rohan Mustafa            4            0           4     PL Mommsen
#
# [1520080 rows x 10 columns]

# %%
match_df.head(6)
# Out:
#     season      city                                         venue  \
# 0  2016/17  Brisbane        Brisbane Cricket Ground, Woolloongabba
# 1  2016/17       N/A                      Melbourne Cricket Ground
# 2  2016/17     Perth  Western Australia Cricket Association Ground
# 3  2016/17       N/A                         Sydney Cricket Ground
# 4  2016/17       N/A                                 Adelaide Oval
# 5  2016/17       N/A                         Sydney Cricket Ground
#
#          date match_type  match_type_number                     teams  \
# 0  2017-01-13        ODI               3817     [Australia, Pakistan]
# 1  2017-01-15        ODI               3818     [Australia, Pakistan]
# 2  2017-01-19        ODI               3820     [Australia, Pakistan]
# 3  2017-01-22        ODI               3822     [Australia, Pakistan]
# 4  2017-01-26        ODI               3826     [Australia, Pakistan]
# 5  2016-12-04        ODI               3811  [Australia, New Zealand]
#
#   toss_winner toss_decision outcome_by_runs outcome_by_wickets     winner  \
# 0   Australia           bat              92                N/A  Australia
# 1   Australia           bat             N/A                  6   Pakistan
# 2   Australia         field             N/A                  7  Australia
# 3   Australia           bat              86                N/A  Australia
# 4   Australia           bat              57                N/A  Australia
# 5   Australia           bat              68                N/A  Australia
#
#    player_of_match target
# 0          MS Wade    269
# 1  Mohammad Hafeez    221
# 2        SPD Smith    264
# 3        DA Warner    354
# 4        DA Warner    370
# 5        SPD Smith    325

# %%
match_df.to_csv("C:/Users/Sajiv/Documents/Cricket/ODI_set/ODI_match_info.csv")

# %%
innings_df.head(6)
# Out:
#     season  match_type_number       team  over     batter         bowler  \
# 0  2016/17               3817  Australia     0  DA Warner  Mohammad Amir
# 1  2016/17               3817  Australia     0  DA Warner  Mohammad Amir
# 2  2016/17               3817  Australia     0  DA Warner  Mohammad Amir
# 3  2016/17               3817  Australia     0  DA Warner  Mohammad Amir
# 4  2016/17               3817  Australia     0  DA Warner  Mohammad Amir
# 5  2016/17               3817  Australia     0  DA Warner  Mohammad Amir
#
#    runs_batter  runs_extras  runs_total non_striker
# 0            0            0           0     TM Head
# 1            0            0           0     TM Head
# 2            0            0           0     TM Head
# 3            0            0           0     TM Head
# 4            0            1           1     TM Head
# 5            0            0           0     TM Head

# %%
innings_df.to_csv("C:/Users/Sajiv/Documents/Cricket/ODI_set/ODI_innings.csv")
